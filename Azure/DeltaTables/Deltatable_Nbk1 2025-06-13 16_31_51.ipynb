# %%
import dlt
from pyspark.sql.functions import col

@dlt.table(name="new_raw_customers")
def load_customers_data():
    return spark.read.csv(
        "dbfs:/FileStore/dlt/customers.csv",
        header=True,
        inferSchema=True
    )

@dlt.table(name="new_raw_orders")
def load_orders_data():
    return spark.read.csv(
        "dbfs:/FileStore/dlt/orders.csv",
        header=True,
        inferSchema=True
    )

@dlt.table(name="new_raw_sales")
def load_sales_data():
    return spark.read.csv(
        "dbfs:/FileStore/dlt/sales_data.csv",
        header=True,
        inferSchema=True
    )
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
# ...
